# %%
# từ chuỗi
import pandas as pd
data=['a','123','cb']
df=pd.DataFrame(data)
print(df)
# Out:
#      0
# 0    a
# 1  123
# 2   cb

# %%
# từ list
import pandas as pd
data=[['a',1],['b',3],['c',2],['d'],'55']
df=pd.DataFrame(data,columns=['fruits','number'])
print(df)
# Out:
#   fruits number
# 0      a      1
# 1      b      3
# 2      c      2
# 3      d   None
# 4      5      5

# %%
import datetime
print("nhập vào ngày tháng năm sinh để tính tuổi")
day_sinh=int(input("ngày sinh:"))
thang_sinh=int(input("tháng sinh:"))
nam_sinh=int(input("namsinh"))
ngayhientai=datetime.date.today().day
thang_hientai=datetime.date.today().month
nam_hientai=datetime.date.today().year
nam_tuoi= nam_hientai-nam_sinh
thang_tuoi=abs(thang_hientai-thang_sinh)
ngay_tuoi=abs(ngayhientai-day_sinh)
print("tuổi là: ",nam_tuoi)
# Out:
# nhập vào ngày tháng năm sinh để tính tuổi
# ngày sinh:02
# tháng sinh:04
# namsinh1985
# tuổi là:  40

# %%
import math
import math
c=10
h=30
value = []
items=[x for x in input("nhap gia tri cua d:").split(',')]
for d in items:
  value.append(str(int(round(math.sqrt(2*c*float(d)/h)))))
print(','.join(value))
# Out:
# nhap gia tri cua d:5
# 2

# %%
items = [x for x in input("nhập:").split(',')]
print(items)
items.sort()
print(','.join(items))
# Out:
# nhập:a,b,1,20.0,4
# ['a', 'b', '1', '20.0', '4']
# 1,20.0,4,a,b

# %%
import numpy as np
import pandas as pd
frame=pd.DataFrame(np.arange(6). reshape(2,1))
print(frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-cbe16ed5abb1> in <cell line: 0>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 frame=pd.DataFrame(np.arange(6). reshape(2,1))
#       4 print(frame)
#
# ValueError: cannot reshape array of size 6 into shape (2,1)
